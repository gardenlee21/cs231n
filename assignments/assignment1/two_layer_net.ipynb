# %%
from google.colab import drive

drive.mount('/content/drive', force_remount=True)

# enter the foldername in your Drive where you have saved the unzipped
# 'cs231n' folder containing the '.py', 'classifiers' and 'datasets'
# folders.
# e.g. 'cs231n/assignments/assignment1/cs231n/'
FOLDERNAME = 'cs231n/assignments/assignment1/cs231n/'

assert FOLDERNAME is not None, "[!] Enter the foldername."

# %cd drive/My\ Drive
# %cp -r $FOLDERNAME ../../
# %cd ../../
# %cd cs231n/datasets/
# !bash get_datasets.sh
# %cd ../../
# Out:
# Mounted at /content/drive
# /content/drive/My Drive
# /content
# /content/cs231n/datasets
# --2021-03-19 10:20:14--  http://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# Resolving www.cs.toronto.edu (www.cs.toronto.edu)... 128.100.3.30
# Connecting to www.cs.toronto.edu (www.cs.toronto.edu)|128.100.3.30|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 170498071 (163M) [application/x-gzip]
# Saving to: ‘cifar-10-python.tar.gz’
#
# cifar-10-python.tar 100%[===================>] 162.60M  73.0MB/s    in 2.2s
#
# 2021-03-19 10:20:17 (73.0 MB/s) - ‘cifar-10-python.tar.gz’ saved [170498071/170498071]
#
# cifar-10-batches-py/
# cifar-10-batches-py/data_batch_4
# cifar-10-batches-py/readme.html
# cifar-10-batches-py/test_batch
# cifar-10-batches-py/data_batch_3
# cifar-10-batches-py/batches.meta
# cifar-10-batches-py/data_batch_2
# cifar-10-batches-py/data_batch_5
# cifar-10-batches-py/data_batch_1
# /content

# %% [markdown]
# # Implementing a Neural Network
# In this exercise we will develop a neural network with fully-connected layers to perform classification, and test it out on the CIFAR-10 dataset.

# %%
# A bit of setup

import numpy as np
import matplotlib.pyplot as plt

from cs231n.classifiers.neural_net import TwoLayerNet

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

def rel_error(x, y):
    """ returns relative error """
    return np.max(np.abs(x - y) / (np.maximum(1e-8, np.abs(x) + np.abs(y))))

# %% [markdown]
# We will use the class `TwoLayerNet` in the file `cs231n/classifiers/neural_net.py` to represent instances of our network. The network parameters are stored in the instance variable `self.params` where keys are string parameter names and values are numpy arrays. Below, we initialize toy data and a toy model that we will use to develop your implementation.

# %%
# Create a small net and some toy data to check your implementations.
# Note that we set the random seed for repeatable experiments.

input_size = 4
hidden_size = 10
num_classes = 3
num_inputs = 5

def init_toy_model():
    np.random.seed(0)
    return TwoLayerNet(input_size, hidden_size, num_classes, std=1e-1)

def init_toy_data():
    np.random.seed(1)
    X = 10 * np.random.randn(num_inputs, input_size)
    y = np.array([0, 1, 2, 2, 1])
    return X, y

net = init_toy_model()
X, y = init_toy_data()

# %% [markdown]
# # Forward pass: compute scores
# Open the file `cs231n/classifiers/neural_net.py` and look at the method `TwoLayerNet.loss`. This function is very similar to the loss functions you have written for the SVM and Softmax exercises: It takes the data and weights and computes the class scores, the loss, and the gradients on the parameters.
#
# Implement the first part of the forward pass which uses the weights and biases to compute the scores for all inputs.

# %%
scores = net.loss(X)
print('Your scores:')
print(scores)
print()
print('correct scores:')
correct_scores = np.asarray([
  [-0.81233741, -1.27654624, -0.70335995],
  [-0.17129677, -1.18803311, -0.47310444],
  [-0.51590475, -1.01354314, -0.8504215 ],
  [-0.15419291, -0.48629638, -0.52901952],
  [-0.00618733, -0.12435261, -0.15226949]])
print(correct_scores)
print()

# The difference should be very small. We get < 1e-7
print('Difference between your scores and correct scores:')
print(np.sum(np.abs(scores - correct_scores)))
# Out:
# Your scores:
# [[-0.81233741 -1.27654624 -0.70335995]
#  [-0.17129677 -1.18803311 -0.47310444]
#  [-0.51590475 -1.01354314 -0.8504215 ]
#  [-0.15419291 -0.48629638 -0.52901952]
#  [-0.00618733 -0.12435261 -0.15226949]]
#
# correct scores:
# [[-0.81233741 -1.27654624 -0.70335995]
#  [-0.17129677 -1.18803311 -0.47310444]
#  [-0.51590475 -1.01354314 -0.8504215 ]
#  [-0.15419291 -0.48629638 -0.52901952]
#  [-0.00618733 -0.12435261 -0.15226949]]
#
# Difference between your scores and correct scores:
# 3.6802720745909845e-08

# %% [markdown]
# # Forward pass: compute loss
# In the same function, implement the second part that computes the data and regularization loss.

# %%
loss, _ = net.loss(X, y, reg=0.05)
correct_loss = 1.30378789133

# should be very small, we get < 1e-12
print('Difference between your loss and correct loss:')
print(np.sum(np.abs(loss - correct_loss)))
# Out:
# Difference between your loss and correct loss:
# 1.794120407794253e-13

# %% [markdown]
# # Backward pass
# Implement the rest of the function. This will compute the gradient of the loss with respect to the variables `W1`, `b1`, `W2`, and `b2`. Now that you (hopefully!) have a correctly implemented forward pass, you can debug your backward pass using a numeric gradient check:

# %%
from cs231n.gradient_check import eval_numerical_gradient

# Use numeric gradient checking to check your implementation of the backward pass.
# If your implementation is correct, the difference between the numeric and
# analytic gradients should be less than 1e-8 for each of W1, W2, b1, and b2.

loss, grads = net.loss(X, y, reg=0.05)

# these should all be less than 1e-8 or so
for param_name in grads:
    f = lambda W: net.loss(X, y, reg=0.05)[0]
    param_grad_num = eval_numerical_gradient(f, net.params[param_name], verbose=False)
    print('%s max relative error: %e' % (param_name, rel_error(param_grad_num, grads[param_name])))
# Out:
# W2 max relative error: 3.440708e-09
# b2 max relative error: 3.865070e-11
# W1 max relative error: 3.561318e-09
# b1 max relative error: 2.738421e-09

# %% [markdown]
# # Train the network
# To train the network we will use stochastic gradient descent (SGD), similar to the SVM and Softmax classifiers. Look at the function `TwoLayerNet.train` and fill in the missing sections to implement the training procedure. This should be very similar to the training procedure you used for the SVM and Softmax classifiers. You will also have to implement `TwoLayerNet.predict`, as the training process periodically performs prediction to keep track of accuracy over time while the network trains.
#
# Once you have implemented the method, run the code below to train a two-layer network on toy data. You should achieve a training loss less than 0.02.

# %%
net = init_toy_model()
stats = net.train(X, y, X, y,
            learning_rate=1e-1, reg=5e-6,
            num_iters=100, verbose=False)

print('Final training loss: ', stats['loss_history'][-1])

# plot the loss history
plt.plot(stats['loss_history'])
plt.xlabel('iteration')
plt.ylabel('training loss')
plt.title('Training Loss history')
plt.show()
# Out:
# Final training loss:  0.01714960793873207

# %% [markdown]
# # Load the data
# Now that you have implemented a two-layer network that passes gradient checks and works on toy data, it's time to load up our favorite CIFAR-10 data so we can use it to train a classifier on a real dataset.

# %%
from cs231n.data_utils import load_CIFAR10

def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000):
    """
    Load the CIFAR-10 dataset from disk and perform preprocessing to prepare
    it for the two-layer neural net classifier. These are the same steps as
    we used for the SVM, but condensed to a single function.  
    """
    # Load the raw CIFAR-10 data
    cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'
    
    # Cleaning up variables to prevent loading data multiple times (which may cause memory issue)
    try:
       del X_train, y_train
       del X_test, y_test
       print('Clear previously loaded data.')
    except:
       pass

    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
        
    # Subsample the data
    mask = list(range(num_training, num_training + num_validation))
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = list(range(num_training))
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = list(range(num_test))
    X_test = X_test[mask]
    y_test = y_test[mask]

    # Normalize the data: subtract the mean image
    mean_image = np.mean(X_train, axis=0)
    X_train -= mean_image
    X_val -= mean_image
    X_test -= mean_image

    # Reshape data to rows
    X_train = X_train.reshape(num_training, -1)
    X_val = X_val.reshape(num_validation, -1)
    X_test = X_test.reshape(num_test, -1)

    return X_train, y_train, X_val, y_val, X_test, y_test


# Invoke the above function to get our data.
X_train, y_train, X_val, y_val, X_test, y_test = get_CIFAR10_data()
print('Train data shape: ', X_train.shape)
print('Train labels shape: ', y_train.shape)
print('Validation data shape: ', X_val.shape)
print('Validation labels shape: ', y_val.shape)
print('Test data shape: ', X_test.shape)
print('Test labels shape: ', y_test.shape)
# Out:
# Train data shape:  (49000, 3072)
# Train labels shape:  (49000,)
# Validation data shape:  (1000, 3072)
# Validation labels shape:  (1000,)
# Test data shape:  (1000, 3072)
# Test labels shape:  (1000,)

# %% [markdown]
# # Train a network
# To train our network we will use SGD. In addition, we will adjust the learning rate with an exponential learning rate schedule as optimization proceeds; after each epoch, we will reduce the learning rate by multiplying it by a decay rate.

# %%
input_size = 32 * 32 * 3
hidden_size = 50
num_classes = 10
net = TwoLayerNet(input_size, hidden_size, num_classes)

# Train the network
stats = net.train(X_train, y_train, X_val, y_val,
            num_iters=1000, batch_size=200,
            learning_rate=1e-4, learning_rate_decay=0.95,
            reg=0.25, verbose=True)

# Predict on the validation set
val_acc = (net.predict(X_val) == y_val).mean()
print('Validation accuracy: ', val_acc)
# Out:
# iteration 0 / 1000: loss 2.302954
# iteration 100 / 1000: loss 2.302550
# iteration 200 / 1000: loss 2.297648
# iteration 300 / 1000: loss 2.259602
# iteration 400 / 1000: loss 2.204170
# iteration 500 / 1000: loss 2.118565
# iteration 600 / 1000: loss 2.051535
# iteration 700 / 1000: loss 1.988466
# iteration 800 / 1000: loss 2.006591
# iteration 900 / 1000: loss 1.951473
# Validation accuracy:  0.287

# %% [markdown]
# # Debug the training
# With the default parameters we provided above, you should get a validation accuracy of about 0.29 on the validation set. This isn't very good.
#
# One strategy for getting insight into what's wrong is to plot the loss function and the accuracies on the training and validation sets during optimization.
#
# Another strategy is to visualize the weights that were learned in the first layer of the network. In most neural networks trained on visual data, the first layer weights typically show some visible structure when visualized.

# %%
# Plot the loss function and train / validation accuracies
plt.subplot(2, 1, 1)
plt.plot(stats['loss_history'])
plt.title('Loss history')
plt.xlabel('Iteration')
plt.ylabel('Loss')

plt.subplot(2, 1, 2)
plt.plot(stats['train_acc_history'], label='train')
plt.plot(stats['val_acc_history'], label='val')
plt.title('Classification accuracy history')
plt.xlabel('Epoch')
plt.ylabel('Classification accuracy')
plt.legend()
plt.show()

# %%
from cs231n.vis_utils import visualize_grid

# Visualize the weights of the network

def show_net_weights(net):
    W1 = net.params['W1']
    W1 = W1.reshape(32, 32, 3, -1).transpose(3, 0, 1, 2)
    plt.imshow(visualize_grid(W1, padding=3).astype('uint8'))
    plt.gca().axis('off')
    plt.show()

show_net_weights(net)

# %% [markdown]
# # Tune your hyperparameters
#
# **What's wrong?**. Looking at the visualizations above, we see that the loss is decreasing more or less linearly, which seems to suggest that the learning rate may be too low. Moreover, there is no gap between the training and validation accuracy, suggesting that the model we used has low capacity, and that we should increase its size. On the other hand, with a very large model we would expect to see more overfitting, which would manifest itself as a very large gap between the training and validation accuracy.
#
# **Tuning**. Tuning the hyperparameters and developing intuition for how they affect the final performance is a large part of using Neural Networks, so we want you to get a lot of practice. Below, you should experiment with different values of the various hyperparameters, including hidden layer size, learning rate, numer of training epochs, and regularization strength. You might also consider tuning the learning rate decay, but you should be able to get good performance using the default value.
#
# **Approximate results**. You should be aim to achieve a classification accuracy of greater than 48% on the validation set. Our best network gets over 52% on the validation set.
#
# **Experiment**: You goal in this exercise is to get as good of a result on CIFAR-10 as you can (52% could serve as a reference), with a fully-connected Neural Network. Feel free implement your own techniques (e.g. PCA to reduce dimensionality, or adding dropout, or adding features to the solver, etc.).

# %% [markdown]
# **Explain your hyperparameter tuning process below.**
#
# $\color{blue}{\textit Your Answer:}$

# %%
best_net = None # store the best model into this 

#################################################################################
# TODO: Tune hyperparameters using the validation set. Store your best trained  #
# model in best_net.                                                            #
#                                                                               #
# To help debug your network, it may help to use visualizations similar to the  #
# ones we used above; these visualizations will have significant qualitative    #
# differences from the ones we saw above for the poorly tuned network.          #
#                                                                               #
# Tweaking hyperparameters by hand can be fun, but you might find it useful to  #
# write code to sweep through possible combinations of hyperparameters          #
# automatically like we did on the previous exercises.                          #
#################################################################################
# *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****

best_val = -1
learning_rates = [1e-4, 2e-4, 3e-4, 4e-4,5e-4]
hidden_size = [100, 200, 300, 400, 500]
results = {}

for hs in hidden_size :
    for lr in learning_rates :
        net = TwoLayerNet(input_size, hs, num_classes)
        net.train(X_train, y_train, X_val, y_val, num_iters=5000, batch_size=200, learning_rate=lr, reg=0.25, verbose=True)
        # Predict on the validation set
        val_acc = (net.predict(X_val) == y_val).mean()
        results[(hs, lr)] = val_acc
        if (val_acc > best_val) :
            best_val = val_acc
            best_net = net
    
# *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****

# Print out results.
for hs, lr in sorted(results):
    val_accuracy = results[(hs, lr)]
    print('hs %e lr %e val accuracy: %f' % (
                hs, lr, val_accuracy))
# Out:
# iteration 0 / 5000: loss 2.303391
# iteration 100 / 5000: loss 2.302742
# iteration 200 / 5000: loss 2.294031
# iteration 300 / 5000: loss 2.226429
# iteration 400 / 5000: loss 2.185848
# iteration 500 / 5000: loss 2.154959
# iteration 600 / 5000: loss 2.094525
# iteration 700 / 5000: loss 2.000721
# iteration 800 / 5000: loss 2.107311
# iteration 900 / 5000: loss 1.972281
# iteration 1000 / 5000: loss 1.936579
# iteration 1100 / 5000: loss 1.964128
# iteration 1200 / 5000: loss 2.055039
# iteration 1300 / 5000: loss 1.845912
# iteration 1400 / 5000: loss 1.841253
# iteration 1500 / 5000: loss 1.783007
# iteration 1600 / 5000: loss 1.885607
# iteration 1700 / 5000: loss 1.821901
# iteration 1800 / 5000: loss 1.855531
# iteration 1900 / 5000: loss 1.833192
# iteration 2000 / 5000: loss 1.764555
# iteration 2100 / 5000: loss 1.847044
# iteration 2200 / 5000: loss 1.860588
# iteration 2300 / 5000: loss 1.704652
# iteration 2400 / 5000: loss 1.739079
# iteration 2500 / 5000: loss 1.744473
# iteration 2600 / 5000: loss 1.782563
# iteration 2700 / 5000: loss 1.739292
# iteration 2800 / 5000: loss 1.769268
# iteration 2900 / 5000: loss 1.754722
# iteration 3000 / 5000: loss 1.675461
# iteration 3100 / 5000: loss 1.694216
# iteration 3200 / 5000: loss 1.775175
# iteration 3300 / 5000: loss 1.637992
# iteration 3400 / 5000: loss 1.657214
# iteration 3500 / 5000: loss 1.703229
# iteration 3600 / 5000: loss 1.723170
# iteration 3700 / 5000: loss 1.788649
# iteration 3800 / 5000: loss 1.729142
# iteration 3900 / 5000: loss 1.718304
# iteration 4000 / 5000: loss 1.745338
# iteration 4100 / 5000: loss 1.603867
# iteration 4200 / 5000: loss 1.681733
# iteration 4300 / 5000: loss 1.640639
# iteration 4400 / 5000: loss 1.613197
# iteration 4500 / 5000: loss 1.646796
# iteration 4600 / 5000: loss 1.721982
# iteration 4700 / 5000: loss 1.612707
# iteration 4800 / 5000: loss 1.693378
# iteration 4900 / 5000: loss 1.578785
# iteration 0 / 5000: loss 2.303370
# iteration 100 / 5000: loss 2.289668
# iteration 200 / 5000: loss 2.203802
# iteration 300 / 5000: loss 1.989243
# iteration 400 / 5000: loss 2.030123
# iteration 500 / 5000: loss 1.853019
# iteration 600 / 5000: loss 1.917357
# iteration 700 / 5000: loss 1.859593
# iteration 800 / 5000: loss 1.825711
# iteration 900 / 5000: loss 1.773384
# iteration 1000 / 5000: loss 1.748251
# iteration 1100 / 5000: loss 1.750448
# iteration 1200 / 5000: loss 1.791070
# iteration 1300 / 5000: loss 1.633560
# iteration 1400 / 5000: loss 1.623867
# iteration 1500 / 5000: loss 1.677308
# iteration 1600 / 5000: loss 1.612922
# iteration 1700 / 5000: loss 1.737479
# iteration 1800 / 5000: loss 1.679372
# iteration 1900 / 5000: loss 1.696879
# iteration 2000 / 5000: loss 1.622455
# iteration 2100 / 5000: loss 1.544604
# iteration 2200 / 5000: loss 1.548405
# iteration 2300 / 5000: loss 1.564240
# iteration 2400 / 5000: loss 1.503872
# iteration 2500 / 5000: loss 1.624462
# iteration 2600 / 5000: loss 1.721901
# iteration 2700 / 5000: loss 1.545648
# iteration 2800 / 5000: loss 1.530359
# iteration 2900 / 5000: loss 1.505195
# iteration 3000 / 5000: loss 1.546221
# iteration 3100 / 5000: loss 1.607662
# iteration 3200 / 5000: loss 1.621104
# iteration 3300 / 5000: loss 1.621217
# iteration 3400 / 5000: loss 1.562602
# iteration 3500 / 5000: loss 1.530879
# iteration 3600 / 5000: loss 1.497273
# iteration 3700 / 5000: loss 1.505003
# iteration 3800 / 5000: loss 1.539940
# iteration 3900 / 5000: loss 1.502479
# iteration 4000 / 5000: loss 1.545627
# iteration 4100 / 5000: loss 1.408308
# iteration 4200 / 5000: loss 1.434759
# iteration 4300 / 5000: loss 1.534692
# iteration 4400 / 5000: loss 1.542157
# iteration 4500 / 5000: loss 1.451600
# iteration 4600 / 5000: loss 1.461583
# iteration 4700 / 5000: loss 1.578652
# iteration 4800 / 5000: loss 1.546581
# iteration 4900 / 5000: loss 1.468316
# iteration 0 / 5000: loss 2.303356
# iteration 100 / 5000: loss 2.228636
# iteration 200 / 5000: loss 2.090098
# iteration 300 / 5000: loss 1.999432
# iteration 400 / 5000: loss 1.919754
# iteration 500 / 5000: loss 1.903439
# iteration 600 / 5000: loss 1.823897
# iteration 700 / 5000: loss 1.720904
# iteration 800 / 5000: loss 1.693548
# iteration 900 / 5000: loss 1.675085
# iteration 1000 / 5000: loss 1.682647
# iteration 1100 / 5000: loss 1.589920
# iteration 1200 / 5000: loss 1.582431
# iteration 1300 / 5000: loss 1.742634
# iteration 1400 / 5000: loss 1.573518
# iteration 1500 / 5000: loss 1.574255
# iteration 1600 / 5000: loss 1.637570
# iteration 1700 / 5000: loss 1.684806
# iteration 1800 / 5000: loss 1.655289
# iteration 1900 / 5000: loss 1.615775
# iteration 2000 / 5000: loss 1.463047
# iteration 2100 / 5000: loss 1.529745
# iteration 2200 / 5000: loss 1.520644
# iteration 2300 / 5000: loss 1.504221
# iteration 2400 / 5000: loss 1.594553
# iteration 2500 / 5000: loss 1.395605
# iteration 2600 / 5000: loss 1.547414
# iteration 2700 / 5000: loss 1.433081
# iteration 2800 / 5000: loss 1.462740
# iteration 2900 / 5000: loss 1.559539
# iteration 3000 / 5000: loss 1.498148
# iteration 3100 / 5000: loss 1.465309
# iteration 3200 / 5000: loss 1.390454
# iteration 3300 / 5000: loss 1.373186
# iteration 3400 / 5000: loss 1.558429
# iteration 3500 / 5000: loss 1.544537
# iteration 3600 / 5000: loss 1.548548
# iteration 3700 / 5000: loss 1.431553
# iteration 3800 / 5000: loss 1.270781
# iteration 3900 / 5000: loss 1.466398
# iteration 4000 / 5000: loss 1.310985
# iteration 4100 / 5000: loss 1.492450
# iteration 4200 / 5000: loss 1.385489
# iteration 4300 / 5000: loss 1.398834
# iteration 4400 / 5000: loss 1.391730
# iteration 4500 / 5000: loss 1.369847
# iteration 4600 / 5000: loss 1.462859
# iteration 4700 / 5000: loss 1.462082
# iteration 4800 / 5000: loss 1.474812
# iteration 4900 / 5000: loss 1.374768
# iteration 0 / 5000: loss 2.303363
# iteration 100 / 5000: loss 2.139041
# iteration 200 / 5000: loss 2.006489
# iteration 300 / 5000: loss 1.806527
# iteration 400 / 5000: loss 1.809595
# iteration 500 / 5000: loss 1.674121
# iteration 600 / 5000: loss 1.772839
# iteration 700 / 5000: loss 1.542716
# iteration 800 / 5000: loss 1.735626
# iteration 900 / 5000: loss 1.734651
# iteration 1000 / 5000: loss 1.661290
# iteration 1100 / 5000: loss 1.618378
# iteration 1200 / 5000: loss 1.686780
# iteration 1300 / 5000: loss 1.619084
# iteration 1400 / 5000: loss 1.752653
# iteration 1500 / 5000: loss 1.544167
# iteration 1600 / 5000: loss 1.529249
# iteration 1700 / 5000: loss 1.627996
# iteration 1800 / 5000: loss 1.536636
# iteration 1900 / 5000: loss 1.526316
# iteration 2000 / 5000: loss 1.463831
# iteration 2100 / 5000: loss 1.531948
# iteration 2200 / 5000: loss 1.431892
# iteration 2300 / 5000: loss 1.294237
# iteration 2400 / 5000: loss 1.530597
# iteration 2500 / 5000: loss 1.440553
# iteration 2600 / 5000: loss 1.457358
# iteration 2700 / 5000: loss 1.563607
# iteration 2800 / 5000: loss 1.467189
# iteration 2900 / 5000: loss 1.493795
# iteration 3000 / 5000: loss 1.343502
# iteration 3100 / 5000: loss 1.472038
# iteration 3200 / 5000: loss 1.434670
# iteration 3300 / 5000: loss 1.503936
# iteration 3400 / 5000: loss 1.297971
# iteration 3500 / 5000: loss 1.506263
# iteration 3600 / 5000: loss 1.442884
# iteration 3700 / 5000: loss 1.427180
# iteration 3800 / 5000: loss 1.477062
# iteration 3900 / 5000: loss 1.437867
# iteration 4000 / 5000: loss 1.436476
# iteration 4100 / 5000: loss 1.316494
# iteration 4200 / 5000: loss 1.351907
# iteration 4300 / 5000: loss 1.477076
# iteration 4400 / 5000: loss 1.395920
# iteration 4500 / 5000: loss 1.452196
# iteration 4600 / 5000: loss 1.531893
# iteration 4700 / 5000: loss 1.368852
# iteration 4800 / 5000: loss 1.418121
# iteration 4900 / 5000: loss 1.382586
# iteration 0 / 5000: loss 2.303352
# iteration 100 / 5000: loss 2.139057
# iteration 200 / 5000: loss 1.887147
# iteration 300 / 5000: loss 1.749272
# iteration 400 / 5000: loss 1.790235
# iteration 500 / 5000: loss 1.658380
# iteration 600 / 5000: loss 1.724217
# iteration 700 / 5000: loss 1.533958
# iteration 800 / 5000: loss 1.650823
# iteration 900 / 5000: loss 1.614291
# iteration 1000 / 5000: loss 1.577770
# iteration 1100 / 5000: loss 1.592004
# iteration 1200 / 5000: loss 1.434704
# iteration 1300 / 5000: loss 1.612484
# iteration 1400 / 5000: loss 1.454977
# iteration 1500 / 5000: loss 1.508186
# iteration 1600 / 5000: loss 1.488199
# iteration 1700 / 5000: loss 1.511885
# iteration 1800 / 5000: loss 1.470191
# iteration 1900 / 5000: loss 1.468873
# iteration 2000 / 5000: loss 1.463684
# iteration 2100 / 5000: loss 1.540326
# iteration 2200 / 5000: loss 1.441415
# iteration 2300 / 5000: loss 1.422160
# iteration 2400 / 5000: loss 1.467787
# iteration 2500 / 5000: loss 1.332408
# iteration 2600 / 5000: loss 1.446434
# iteration 2700 / 5000: loss 1.428429
# iteration 2800 / 5000: loss 1.312735
# iteration 2900 / 5000: loss 1.381478
# iteration 3000 / 5000: loss 1.436658
# iteration 3100 / 5000: loss 1.342233
# iteration 3200 / 5000: loss 1.469976
# iteration 3300 / 5000: loss 1.571805
# iteration 3400 / 5000: loss 1.561390
# iteration 3500 / 5000: loss 1.324728
# iteration 3600 / 5000: loss 1.476203
# iteration 3700 / 5000: loss 1.345378
# iteration 3800 / 5000: loss 1.307048
# iteration 3900 / 5000: loss 1.309589
# iteration 4000 / 5000: loss 1.416718
# iteration 4100 / 5000: loss 1.345414
# iteration 4200 / 5000: loss 1.393161
# iteration 4300 / 5000: loss 1.443132
# iteration 4400 / 5000: loss 1.255369
# iteration 4500 / 5000: loss 1.346281
# iteration 4600 / 5000: loss 1.355010
# iteration 4700 / 5000: loss 1.332745
# iteration 4800 / 5000: loss 1.496479
# iteration 4900 / 5000: loss 1.231936
# iteration 0 / 5000: loss 2.304110
# iteration 100 / 5000: loss 2.302362
# iteration 200 / 5000: loss 2.281244
# iteration 300 / 5000: loss 2.241916
# iteration 400 / 5000: loss 2.098117
# iteration 500 / 5000: loss 2.082901
# iteration 600 / 5000: loss 2.019430
# iteration 700 / 5000: loss 2.055681
# iteration 800 / 5000: loss 1.927435
# iteration 900 / 5000: loss 1.909183
# iteration 1000 / 5000: loss 1.931531
# iteration 1100 / 5000: loss 1.892143
# iteration 1200 / 5000: loss 1.907122
# iteration 1300 / 5000: loss 1.891563
# iteration 1400 / 5000: loss 1.750116
# iteration 1500 / 5000: loss 1.770109
# iteration 1600 / 5000: loss 1.901850
# iteration 1700 / 5000: loss 1.861912
# iteration 1800 / 5000: loss 1.865010
# iteration 1900 / 5000: loss 1.823972
# iteration 2000 / 5000: loss 1.820850
# iteration 2100 / 5000: loss 1.864111
# iteration 2200 / 5000: loss 1.612423
# iteration 2300 / 5000: loss 1.781248
# iteration 2400 / 5000: loss 1.706877
# iteration 2500 / 5000: loss 1.769108
# iteration 2600 / 5000: loss 1.673381
# iteration 2700 / 5000: loss 1.769241
# iteration 2800 / 5000: loss 1.643548
# iteration 2900 / 5000: loss 1.731583
# iteration 3000 / 5000: loss 1.761801
# iteration 3100 / 5000: loss 1.749713
# iteration 3200 / 5000: loss 1.726393
# iteration 3300 / 5000: loss 1.674150
# iteration 3400 / 5000: loss 1.643435
# iteration 3500 / 5000: loss 1.712473
# iteration 3600 / 5000: loss 1.658581
# iteration 3700 / 5000: loss 1.601472
# iteration 3800 / 5000: loss 1.680965
# iteration 3900 / 5000: loss 1.635500
# iteration 4000 / 5000: loss 1.674803
# iteration 4100 / 5000: loss 1.646443
# iteration 4200 / 5000: loss 1.622752
# iteration 4300 / 5000: loss 1.667696
# iteration 4400 / 5000: loss 1.674366
# iteration 4500 / 5000: loss 1.543076
# iteration 4600 / 5000: loss 1.653321
# iteration 4700 / 5000: loss 1.548582
# iteration 4800 / 5000: loss 1.688143
# iteration 4900 / 5000: loss 1.573037
# iteration 0 / 5000: loss 2.304162
# iteration 100 / 5000: loss 2.290231
# iteration 200 / 5000: loss 2.146035
# iteration 300 / 5000: loss 2.046964
# iteration 400 / 5000: loss 1.976219
# iteration 500 / 5000: loss 1.948939
# iteration 600 / 5000: loss 1.854278
# iteration 700 / 5000: loss 1.832894
# iteration 800 / 5000: loss 1.816321
# iteration 900 / 5000: loss 1.774984
# iteration 1000 / 5000: loss 1.699918
# iteration 1100 / 5000: loss 1.655461
# iteration 1200 / 5000: loss 1.683308
# iteration 1300 / 5000: loss 1.666661
# iteration 1400 / 5000: loss 1.763830
# iteration 1500 / 5000: loss 1.694461
# iteration 1600 / 5000: loss 1.717373
# iteration 1700 / 5000: loss 1.730407
# iteration 1800 / 5000: loss 1.547798
# iteration 1900 / 5000: loss 1.550503
# iteration 2000 / 5000: loss 1.654609
# iteration 2100 / 5000: loss 1.664542
# iteration 2200 / 5000: loss 1.668493
# iteration 2300 / 5000: loss 1.675126
# iteration 2400 / 5000: loss 1.602607
# iteration 2500 / 5000: loss 1.595901
# iteration 2600 / 5000: loss 1.555497
# iteration 2700 / 5000: loss 1.451559
# iteration 2800 / 5000: loss 1.594906
# iteration 2900 / 5000: loss 1.531866
# iteration 3000 / 5000: loss 1.502462
# iteration 3100 / 5000: loss 1.598422
# iteration 3200 / 5000: loss 1.728809
# iteration 3300 / 5000: loss 1.510681
# iteration 3400 / 5000: loss 1.580782
# iteration 3500 / 5000: loss 1.404040
# iteration 3600 / 5000: loss 1.600854
# iteration 3700 / 5000: loss 1.443788
# iteration 3800 / 5000: loss 1.536967
# iteration 3900 / 5000: loss 1.571485
# iteration 4000 / 5000: loss 1.607386
# iteration 4100 / 5000: loss 1.548825
# iteration 4200 / 5000: loss 1.542388
# iteration 4300 / 5000: loss 1.495493
# iteration 4400 / 5000: loss 1.413858
# iteration 4500 / 5000: loss 1.507839
# iteration 4600 / 5000: loss 1.534272
# iteration 4700 / 5000: loss 1.556397
# iteration 4800 / 5000: loss 1.477336
# iteration 4900 / 5000: loss 1.425244
# iteration 0 / 5000: loss 2.304129
# iteration 100 / 5000: loss 2.219570
# iteration 200 / 5000: loss 2.038284
# iteration 300 / 5000: loss 1.919618
# iteration 400 / 5000: loss 1.889099
# iteration 500 / 5000: loss 1.815669
# iteration 600 / 5000: loss 1.753816
# iteration 700 / 5000: loss 1.797906
# iteration 800 / 5000: loss 1.729741
# iteration 900 / 5000: loss 1.616949
# iteration 1000 / 5000: loss 1.623333
# iteration 1100 / 5000: loss 1.707938
# iteration 1200 / 5000: loss 1.772855
# iteration 1300 / 5000: loss 1.633790
# iteration 1400 / 5000: loss 1.643231
# iteration 1500 / 5000: loss 1.589650
# iteration 1600 / 5000: loss 1.645716
# iteration 1700 / 5000: loss 1.511349
# iteration 1800 / 5000: loss 1.498072
# iteration 1900 / 5000: loss 1.569783
# iteration 2000 / 5000: loss 1.561758
# iteration 2100 / 5000: loss 1.575753
# iteration 2200 / 5000: loss 1.550145
# iteration 2300 / 5000: loss 1.582418
# iteration 2400 / 5000: loss 1.552519
# iteration 2500 / 5000: loss 1.533072
# iteration 2600 / 5000: loss 1.509874
# iteration 2700 / 5000: loss 1.447491
# iteration 2800 / 5000: loss 1.523757
# iteration 2900 / 5000: loss 1.380996
# iteration 3000 / 5000: loss 1.391884
# iteration 3100 / 5000: loss 1.315835
# iteration 3200 / 5000: loss 1.484399
# iteration 3300 / 5000: loss 1.444485
# iteration 3400 / 5000: loss 1.407658
# iteration 3500 / 5000: loss 1.428262
# iteration 3600 / 5000: loss 1.393120
# iteration 3700 / 5000: loss 1.364229
# iteration 3800 / 5000: loss 1.469600
# iteration 3900 / 5000: loss 1.494282
# iteration 4000 / 5000: loss 1.533687
# iteration 4100 / 5000: loss 1.528539
# iteration 4200 / 5000: loss 1.474675
# iteration 4300 / 5000: loss 1.526160
# iteration 4400 / 5000: loss 1.419406
# iteration 4500 / 5000: loss 1.364149
# iteration 4600 / 5000: loss 1.524450
# iteration 4700 / 5000: loss 1.509103
# iteration 4800 / 5000: loss 1.305611
# iteration 4900 / 5000: loss 1.380971
# iteration 0 / 5000: loss 2.304161
# iteration 100 / 5000: loss 2.190443
# iteration 200 / 5000: loss 1.917138
# iteration 300 / 5000: loss 1.831544
# iteration 400 / 5000: loss 1.739305
# iteration 500 / 5000: loss 1.662840
# iteration 600 / 5000: loss 1.695445
# iteration 700 / 5000: loss 1.771958
# iteration 800 / 5000: loss 1.716041
# iteration 900 / 5000: loss 1.682976
# iteration 1000 / 5000: loss 1.610377
# iteration 1100 / 5000: loss 1.600416
# iteration 1200 / 5000: loss 1.426570
# iteration 1300 / 5000: loss 1.616194
# iteration 1400 / 5000: loss 1.517019
# iteration 1500 / 5000: loss 1.617207
# iteration 1600 / 5000: loss 1.511420
# iteration 1700 / 5000: loss 1.629539
# iteration 1800 / 5000: loss 1.528461
# iteration 1900 / 5000: loss 1.616692
# iteration 2000 / 5000: loss 1.497874
# iteration 2100 / 5000: loss 1.385199
# iteration 2200 / 5000: loss 1.432524
# iteration 2300 / 5000: loss 1.418761
# iteration 2400 / 5000: loss 1.363637
# iteration 2500 / 5000: loss 1.452474
# iteration 2600 / 5000: loss 1.423281
# iteration 2700 / 5000: loss 1.357678
# iteration 2800 / 5000: loss 1.437060
# iteration 2900 / 5000: loss 1.481473
# iteration 3000 / 5000: loss 1.359908
# iteration 3100 / 5000: loss 1.325691
# iteration 3200 / 5000: loss 1.437024
# iteration 3300 / 5000: loss 1.296727
# iteration 3400 / 5000: loss 1.461803
# iteration 3500 / 5000: loss 1.485663
# iteration 3600 / 5000: loss 1.444108
# iteration 3700 / 5000: loss 1.394051
# iteration 3800 / 5000: loss 1.518253
# iteration 3900 / 5000: loss 1.365185
# iteration 4000 / 5000: loss 1.377389
# iteration 4100 / 5000: loss 1.357508
# iteration 4200 / 5000: loss 1.476633
# iteration 4300 / 5000: loss 1.263708
# iteration 4400 / 5000: loss 1.320533
# iteration 4500 / 5000: loss 1.301825
# iteration 4600 / 5000: loss 1.330031
# iteration 4700 / 5000: loss 1.385820
# iteration 4800 / 5000: loss 1.418867
# iteration 4900 / 5000: loss 1.326274
# iteration 0 / 5000: loss 2.304157
# iteration 100 / 5000: loss 2.081310
# iteration 200 / 5000: loss 1.928874
# iteration 300 / 5000: loss 1.746136
# iteration 400 / 5000: loss 1.723092
# iteration 500 / 5000: loss 1.609871
# iteration 600 / 5000: loss 1.647448
# iteration 700 / 5000: loss 1.498773
# iteration 800 / 5000: loss 1.600501
# iteration 900 / 5000: loss 1.568263
# iteration 1000 / 5000: loss 1.569502
# iteration 1100 / 5000: loss 1.496081
# iteration 1200 / 5000: loss 1.529464
# iteration 1300 / 5000: loss 1.638345
# iteration 1400 / 5000: loss 1.664626
# iteration 1500 / 5000: loss 1.525467
# iteration 1600 / 5000: loss 1.619384
# iteration 1700 / 5000: loss 1.447463
# iteration 1800 / 5000: loss 1.510430
# iteration 1900 / 5000: loss 1.468009
# iteration 2000 / 5000: loss 1.599300
# iteration 2100 / 5000: loss 1.464111
# iteration 2200 / 5000: loss 1.438981
# iteration 2300 / 5000: loss 1.456849
# iteration 2400 / 5000: loss 1.527198
# iteration 2500 / 5000: loss 1.425111
# iteration 2600 / 5000: loss 1.432552
# iteration 2700 / 5000: loss 1.353324
# iteration 2800 / 5000: loss 1.456647
# iteration 2900 / 5000: loss 1.458890
# iteration 3000 / 5000: loss 1.377889
# iteration 3100 / 5000: loss 1.303158
# iteration 3200 / 5000: loss 1.432267
# iteration 3300 / 5000: loss 1.357601
# iteration 3400 / 5000: loss 1.431076
# iteration 3500 / 5000: loss 1.420108
# iteration 3600 / 5000: loss 1.355225
# iteration 3700 / 5000: loss 1.415225
# iteration 3800 / 5000: loss 1.365686
# iteration 3900 / 5000: loss 1.302439
# iteration 4000 / 5000: loss 1.305832
# iteration 4100 / 5000: loss 1.302353
# iteration 4200 / 5000: loss 1.334025
# iteration 4300 / 5000: loss 1.213709
# iteration 4400 / 5000: loss 1.309426
# iteration 4500 / 5000: loss 1.440170
# iteration 4600 / 5000: loss 1.308650
# iteration 4700 / 5000: loss 1.319115
# iteration 4800 / 5000: loss 1.309566
# iteration 4900 / 5000: loss 1.353693
# iteration 0 / 5000: loss 2.304860
# iteration 100 / 5000: loss 2.301506
# iteration 200 / 5000: loss 2.279240
# iteration 300 / 5000: loss 2.173554
# iteration 400 / 5000: loss 2.133808
# iteration 500 / 5000: loss 2.057933
# iteration 600 / 5000: loss 2.110498
# iteration 700 / 5000: loss 2.058986
# iteration 800 / 5000: loss 2.058814
# iteration 900 / 5000: loss 1.927238
# iteration 1000 / 5000: loss 1.804591
# iteration 1100 / 5000: loss 1.886711
# iteration 1200 / 5000: loss 1.880927
# iteration 1300 / 5000: loss 1.915599
# iteration 1400 / 5000: loss 1.828526
# iteration 1500 / 5000: loss 1.854195
# iteration 1600 / 5000: loss 1.791273
# iteration 1700 / 5000: loss 1.778164
# iteration 1800 / 5000: loss 1.834187
# iteration 1900 / 5000: loss 1.697827
# iteration 2000 / 5000: loss 1.829770
# iteration 2100 / 5000: loss 1.811982
# iteration 2200 / 5000: loss 1.791043
# iteration 2300 / 5000: loss 1.756626
# iteration 2400 / 5000: loss 1.707494
# iteration 2500 / 5000: loss 1.811244
# iteration 2600 / 5000: loss 1.740193
# iteration 2700 / 5000: loss 1.759374
# iteration 2800 / 5000: loss 1.708631
# iteration 2900 / 5000: loss 1.664562
# iteration 3000 / 5000: loss 1.826387
# iteration 3100 / 5000: loss 1.670372
# iteration 3200 / 5000: loss 1.669287
# iteration 3300 / 5000: loss 1.673442
# iteration 3400 / 5000: loss 1.734463
# iteration 3500 / 5000: loss 1.647907
# iteration 3600 / 5000: loss 1.831294
# iteration 3700 / 5000: loss 1.738066
# iteration 3800 / 5000: loss 1.607988
# iteration 3900 / 5000: loss 1.640113
# iteration 4000 / 5000: loss 1.696004
# iteration 4100 / 5000: loss 1.821832
# iteration 4200 / 5000: loss 1.602379
# iteration 4300 / 5000: loss 1.574700
# iteration 4400 / 5000: loss 1.616331
# iteration 4500 / 5000: loss 1.699943
# iteration 4600 / 5000: loss 1.665246
# iteration 4700 / 5000: loss 1.644166
# iteration 4800 / 5000: loss 1.553247
# iteration 4900 / 5000: loss 1.633683
# iteration 0 / 5000: loss 2.304892
# iteration 100 / 5000: loss 2.282615
# iteration 200 / 5000: loss 2.117492
# iteration 300 / 5000: loss 2.018717
# iteration 400 / 5000: loss 1.984580
# iteration 500 / 5000: loss 1.910779
# iteration 600 / 5000: loss 1.763968
# iteration 700 / 5000: loss 1.825769
# iteration 800 / 5000: loss 1.787455
# iteration 900 / 5000: loss 1.769357
# iteration 1000 / 5000: loss 1.817180
# iteration 1100 / 5000: loss 1.664167
# iteration 1200 / 5000: loss 1.765994
# iteration 1300 / 5000: loss 1.766626
# iteration 1400 / 5000: loss 1.638617
# iteration 1500 / 5000: loss 1.663900
# iteration 1600 / 5000: loss 1.571799
# iteration 1700 / 5000: loss 1.599771
# iteration 1800 / 5000: loss 1.769002
# iteration 1900 / 5000: loss 1.688888
# iteration 2000 / 5000: loss 1.644741
# iteration 2100 / 5000: loss 1.597628
# iteration 2200 / 5000: loss 1.611976
# iteration 2300 / 5000: loss 1.585437
# iteration 2400 / 5000: loss 1.446650
# iteration 2500 / 5000: loss 1.477956
# iteration 2600 / 5000: loss 1.474867
# iteration 2700 / 5000: loss 1.532471
# iteration 2800 / 5000: loss 1.463731
# iteration 2900 / 5000: loss 1.616202
# iteration 3000 / 5000: loss 1.555928
# iteration 3100 / 5000: loss 1.596483
# iteration 3200 / 5000: loss 1.545084
# iteration 3300 / 5000: loss 1.540016
# iteration 3400 / 5000: loss 1.505195
# iteration 3500 / 5000: loss 1.480523
# iteration 3600 / 5000: loss 1.558679
# iteration 3700 / 5000: loss 1.546425
# iteration 3800 / 5000: loss 1.495879
# iteration 3900 / 5000: loss 1.546203
# iteration 4000 / 5000: loss 1.563013
# iteration 4100 / 5000: loss 1.425232
# iteration 4200 / 5000: loss 1.553953
# iteration 4300 / 5000: loss 1.494759
# iteration 4400 / 5000: loss 1.579944
# iteration 4500 / 5000: loss 1.623164
# iteration 4600 / 5000: loss 1.511797
# iteration 4700 / 5000: loss 1.544327
# iteration 4800 / 5000: loss 1.590465
# iteration 4900 / 5000: loss 1.504526
# iteration 0 / 5000: loss 2.304920
# iteration 100 / 5000: loss 2.206072
# iteration 200 / 5000: loss 1.980329
# iteration 300 / 5000: loss 1.993653
# iteration 400 / 5000: loss 1.858307
# iteration 500 / 5000: loss 1.843775
# iteration 600 / 5000: loss 1.758578
# iteration 700 / 5000: loss 1.764887
# iteration 800 / 5000: loss 1.723573
# iteration 900 / 5000: loss 1.709542
# iteration 1000 / 5000: loss 1.597353
# iteration 1100 / 5000: loss 1.629794
# iteration 1200 / 5000: loss 1.638401
# iteration 1300 / 5000: loss 1.554813
# iteration 1400 / 5000: loss 1.669498
# iteration 1500 / 5000: loss 1.703358
# iteration 1600 / 5000: loss 1.576017
# iteration 1700 / 5000: loss 1.620424
# iteration 1800 / 5000: loss 1.522000
# iteration 1900 / 5000: loss 1.566869
# iteration 2000 / 5000: loss 1.515527
# iteration 2100 / 5000: loss 1.513086
# iteration 2200 / 5000: loss 1.482196
# iteration 2300 / 5000: loss 1.448055
# iteration 2400 / 5000: loss 1.450851
# iteration 2500 / 5000: loss 1.336531
# iteration 2600 / 5000: loss 1.424007
# iteration 2700 / 5000: loss 1.464571
# iteration 2800 / 5000: loss 1.545770
# iteration 2900 / 5000: loss 1.531264
# iteration 3000 / 5000: loss 1.530591
# iteration 3100 / 5000: loss 1.421040
# iteration 3200 / 5000: loss 1.536157
# iteration 3300 / 5000: loss 1.393169
# iteration 3400 / 5000: loss 1.565993
# iteration 3500 / 5000: loss 1.583937
# iteration 3600 / 5000: loss 1.510306
# iteration 3700 / 5000: loss 1.446454
# iteration 3800 / 5000: loss 1.362551
# iteration 3900 / 5000: loss 1.450178
# iteration 4000 / 5000: loss 1.429234
# iteration 4100 / 5000: loss 1.367428
# iteration 4200 / 5000: loss 1.443610
# iteration 4300 / 5000: loss 1.456123
# iteration 4400 / 5000: loss 1.468001
# iteration 4500 / 5000: loss 1.591703
# iteration 4600 / 5000: loss 1.376267
# iteration 4700 / 5000: loss 1.414705
# iteration 4800 / 5000: loss 1.453383
# iteration 4900 / 5000: loss 1.403104
# iteration 0 / 5000: loss 2.304941
# iteration 100 / 5000: loss 2.118490
# iteration 200 / 5000: loss 1.907376
# iteration 300 / 5000: loss 1.848452
# iteration 400 / 5000: loss 1.849182
# iteration 500 / 5000: loss 1.788165
# iteration 600 / 5000: loss 1.649668
# iteration 700 / 5000: loss 1.725135
# iteration 800 / 5000: loss 1.664185
# iteration 900 / 5000: loss 1.700381
# iteration 1000 / 5000: loss 1.740700
# iteration 1100 / 5000: loss 1.583172
# iteration 1200 / 5000: loss 1.607007
# iteration 1300 / 5000: loss 1.578061
# iteration 1400 / 5000: loss 1.641768
# iteration 1500 / 5000: loss 1.540889
# iteration 1600 / 5000: loss 1.511319
# iteration 1700 / 5000: loss 1.538969
# iteration 1800 / 5000: loss 1.534399
# iteration 1900 / 5000: loss 1.420994
# iteration 2000 / 5000: loss 1.366349
# iteration 2100 / 5000: loss 1.565724
# iteration 2200 / 5000: loss 1.485348
# iteration 2300 / 5000: loss 1.471557
# iteration 2400 / 5000: loss 1.281504
# iteration 2500 / 5000: loss 1.401383
# iteration 2600 / 5000: loss 1.451636
# iteration 2700 / 5000: loss 1.349693
# iteration 2800 / 5000: loss 1.460882
# iteration 2900 / 5000: loss 1.453525
# iteration 3000 / 5000: loss 1.534212
# iteration 3100 / 5000: loss 1.641703
# iteration 3200 / 5000: loss 1.342877
# iteration 3300 / 5000: loss 1.437881
# iteration 3400 / 5000: loss 1.465351
# iteration 3500 / 5000: loss 1.262030
# iteration 3600 / 5000: loss 1.363302
# iteration 3700 / 5000: loss 1.453424
# iteration 3800 / 5000: loss 1.342280
# iteration 3900 / 5000: loss 1.454483
# iteration 4000 / 5000: loss 1.470497
# iteration 4100 / 5000: loss 1.436550
# iteration 4200 / 5000: loss 1.327964
# iteration 4300 / 5000: loss 1.515145
# iteration 4400 / 5000: loss 1.302452
# iteration 4500 / 5000: loss 1.235113
# iteration 4600 / 5000: loss 1.407414
# iteration 4700 / 5000: loss 1.242511
# iteration 4800 / 5000: loss 1.266007
# iteration 4900 / 5000: loss 1.329409
# iteration 0 / 5000: loss 2.304865
# iteration 100 / 5000: loss 2.051070
# iteration 200 / 5000: loss 1.863729
# iteration 300 / 5000: loss 1.780597
# iteration 400 / 5000: loss 1.788939
# iteration 500 / 5000: loss 1.664680
# iteration 600 / 5000: loss 1.685605
# iteration 700 / 5000: loss 1.724347
# iteration 800 / 5000: loss 1.691280
# iteration 900 / 5000: loss 1.592426
# iteration 1000 / 5000: loss 1.679234
# iteration 1100 / 5000: loss 1.553617
# iteration 1200 / 5000: loss 1.582821
# iteration 1300 / 5000: loss 1.620261
# iteration 1400 / 5000: loss 1.317413
# iteration 1500 / 5000: loss 1.425857
# iteration 1600 / 5000: loss 1.453637
# iteration 1700 / 5000: loss 1.518371
# iteration 1800 / 5000: loss 1.488981
# iteration 1900 / 5000: loss 1.321027
# iteration 2000 / 5000: loss 1.474002
# iteration 2100 / 5000: loss 1.477716
# iteration 2200 / 5000: loss 1.479002
# iteration 2300 / 5000: loss 1.408298
# iteration 2400 / 5000: loss 1.418583
# iteration 2500 / 5000: loss 1.464892
# iteration 2600 / 5000: loss 1.348647
# iteration 2700 / 5000: loss 1.368487
# iteration 2800 / 5000: loss 1.326022
# iteration 2900 / 5000: loss 1.400555
# iteration 3000 / 5000: loss 1.392265
# iteration 3100 / 5000: loss 1.343552
# iteration 3200 / 5000: loss 1.325616
# iteration 3300 / 5000: loss 1.342642
# iteration 3400 / 5000: loss 1.297630
# iteration 3500 / 5000: loss 1.250613
# iteration 3600 / 5000: loss 1.299617
# iteration 3700 / 5000: loss 1.255489
# iteration 3800 / 5000: loss 1.314589
# iteration 3900 / 5000: loss 1.279911
# iteration 4000 / 5000: loss 1.362265
# iteration 4100 / 5000: loss 1.396489
# iteration 4200 / 5000: loss 1.370758
# iteration 4300 / 5000: loss 1.321544
# iteration 4400 / 5000: loss 1.398981
# iteration 4500 / 5000: loss 1.288267
# iteration 4600 / 5000: loss 1.354595
# iteration 4700 / 5000: loss 1.189292
# iteration 4800 / 5000: loss 1.291340
# iteration 4900 / 5000: loss 1.294012
# iteration 0 / 5000: loss 2.305636
# iteration 100 / 5000: loss 2.302454
# iteration 200 / 5000: loss 2.271679
# iteration 300 / 5000: loss 2.183460
# iteration 400 / 5000: loss 2.107176
# iteration 500 / 5000: loss 2.058212
# iteration 600 / 5000: loss 2.061738
# iteration 700 / 5000: loss 1.938475
# iteration 800 / 5000: loss 1.930445
# iteration 900 / 5000: loss 1.822911
# iteration 1000 / 5000: loss 1.919331
# iteration 1100 / 5000: loss 1.962370
# iteration 1200 / 5000: loss 1.871684
# iteration 1300 / 5000: loss 1.790392
# iteration 1400 / 5000: loss 1.859464
# iteration 1500 / 5000: loss 1.812171
# iteration 1600 / 5000: loss 1.779278
# iteration 1700 / 5000: loss 1.869155
# iteration 1800 / 5000: loss 1.667504
# iteration 1900 / 5000: loss 1.811779
# iteration 2000 / 5000: loss 1.722985
# iteration 2100 / 5000: loss 1.680179
# iteration 2200 / 5000: loss 1.683982
# iteration 2300 / 5000: loss 1.633238
# iteration 2400 / 5000: loss 1.706947
# iteration 2500 / 5000: loss 1.727490
# iteration 2600 / 5000: loss 1.737447
# iteration 2700 / 5000: loss 1.740214
# iteration 2800 / 5000: loss 1.836849
# iteration 2900 / 5000: loss 1.735481
# iteration 3000 / 5000: loss 1.619511
# iteration 3100 / 5000: loss 1.654482
# iteration 3200 / 5000: loss 1.662679
# iteration 3300 / 5000: loss 1.641279
# iteration 3400 / 5000: loss 1.735199
# iteration 3500 / 5000: loss 1.628222
# iteration 3600 / 5000: loss 1.633594
# iteration 3700 / 5000: loss 1.670383
# iteration 3800 / 5000: loss 1.634537
# iteration 3900 / 5000: loss 1.647659
# iteration 4000 / 5000: loss 1.644788
# iteration 4100 / 5000: loss 1.621213
# iteration 4200 / 5000: loss 1.617913
# iteration 4300 / 5000: loss 1.727191
# iteration 4400 / 5000: loss 1.602670
# iteration 4500 / 5000: loss 1.588984
# iteration 4600 / 5000: loss 1.444044
# iteration 4700 / 5000: loss 1.522777
# iteration 4800 / 5000: loss 1.624493
# iteration 4900 / 5000: loss 1.665056
# iteration 0 / 5000: loss 2.305600
# iteration 100 / 5000: loss 2.267349
# iteration 200 / 5000: loss 2.168849
# iteration 300 / 5000: loss 1.964350
# iteration 400 / 5000: loss 1.900294
# iteration 500 / 5000: loss 1.957339
# iteration 600 / 5000: loss 1.841316
# iteration 700 / 5000: loss 1.707098
# iteration 800 / 5000: loss 1.822920
# iteration 900 / 5000: loss 1.725567
# iteration 1000 / 5000: loss 1.815242
# iteration 1100 / 5000: loss 1.638307
# iteration 1200 / 5000: loss 1.721011
# iteration 1300 / 5000: loss 1.697552
# iteration 1400 / 5000: loss 1.692365
# iteration 1500 / 5000: loss 1.691531
# iteration 1600 / 5000: loss 1.689322
# iteration 1700 / 5000: loss 1.564799
# iteration 1800 / 5000: loss 1.806248
# iteration 1900 / 5000: loss 1.821537
# iteration 2000 / 5000: loss 1.511739
# iteration 2100 / 5000: loss 1.690990
# iteration 2200 / 5000: loss 1.634952
# iteration 2300 / 5000: loss 1.482093
# iteration 2400 / 5000: loss 1.643595
# iteration 2500 / 5000: loss 1.561501
# iteration 2600 / 5000: loss 1.570817
# iteration 2700 / 5000: loss 1.577494
# iteration 2800 / 5000: loss 1.594240
# iteration 2900 / 5000: loss 1.522933
# iteration 3000 / 5000: loss 1.437460
# iteration 3100 / 5000: loss 1.614078
# iteration 3200 / 5000: loss 1.525426
# iteration 3300 / 5000: loss 1.463156
# iteration 3400 / 5000: loss 1.462150
# iteration 3500 / 5000: loss 1.578755
# iteration 3600 / 5000: loss 1.485329
# iteration 3700 / 5000: loss 1.541848
# iteration 3800 / 5000: loss 1.664232
# iteration 3900 / 5000: loss 1.503512
# iteration 4000 / 5000: loss 1.501803
# iteration 4100 / 5000: loss 1.512026
# iteration 4200 / 5000: loss 1.493224
# iteration 4300 / 5000: loss 1.462167
# iteration 4400 / 5000: loss 1.455757
# iteration 4500 / 5000: loss 1.546975
# iteration 4600 / 5000: loss 1.485016
# iteration 4700 / 5000: loss 1.518322
# iteration 4800 / 5000: loss 1.478827
# iteration 4900 / 5000: loss 1.453046
# iteration 0 / 5000: loss 2.305615
# iteration 100 / 5000: loss 2.151485
# iteration 200 / 5000: loss 1.985676
# iteration 300 / 5000: loss 1.943111
# iteration 400 / 5000: loss 1.913273
# iteration 500 / 5000: loss 1.708666
# iteration 600 / 5000: loss 1.827180
# iteration 700 / 5000: loss 1.694343
# iteration 800 / 5000: loss 1.733326
# iteration 900 / 5000: loss 1.596069
# iteration 1000 / 5000: loss 1.663410
# iteration 1100 / 5000: loss 1.678386
# iteration 1200 / 5000: loss 1.647348
# iteration 1300 / 5000: loss 1.621091
# iteration 1400 / 5000: loss 1.531054
# iteration 1500 / 5000: loss 1.573818
# iteration 1600 / 5000: loss 1.652278
# iteration 1700 / 5000: loss 1.505817
# iteration 1800 / 5000: loss 1.602645
# iteration 1900 / 5000: loss 1.530450
# iteration 2000 / 5000: loss 1.477093
# iteration 2100 / 5000: loss 1.539312
# iteration 2200 / 5000: loss 1.485300
# iteration 2300 / 5000: loss 1.467691
# iteration 2400 / 5000: loss 1.495584
# iteration 2500 / 5000: loss 1.479947
# iteration 2600 / 5000: loss 1.429117
# iteration 2700 / 5000: loss 1.387923
# iteration 2800 / 5000: loss 1.473693
# iteration 2900 / 5000: loss 1.432243
# iteration 3000 / 5000: loss 1.505219
# iteration 3100 / 5000: loss 1.450284
# iteration 3200 / 5000: loss 1.464332
# iteration 3300 / 5000: loss 1.415594
# iteration 3400 / 5000: loss 1.436758
# iteration 3500 / 5000: loss 1.420441
# iteration 3600 / 5000: loss 1.448126
# iteration 3700 / 5000: loss 1.282824
# iteration 3800 / 5000: loss 1.412805
# iteration 3900 / 5000: loss 1.458821
# iteration 4000 / 5000: loss 1.405787
# iteration 4100 / 5000: loss 1.422224
# iteration 4200 / 5000: loss 1.396174
# iteration 4300 / 5000: loss 1.298329
# iteration 4400 / 5000: loss 1.414537
# iteration 4500 / 5000: loss 1.472041
# iteration 4600 / 5000: loss 1.404285
# iteration 4700 / 5000: loss 1.446413
# iteration 4800 / 5000: loss 1.432058
# iteration 4900 / 5000: loss 1.489273
# iteration 0 / 5000: loss 2.305621
# iteration 100 / 5000: loss 2.156451
# iteration 200 / 5000: loss 2.013688
# iteration 300 / 5000: loss 1.855620
# iteration 400 / 5000: loss 1.854946
# iteration 500 / 5000: loss 1.687798
# iteration 600 / 5000: loss 1.751534
# iteration 700 / 5000: loss 1.618819
# iteration 800 / 5000: loss 1.642128
# iteration 900 / 5000: loss 1.617511
# iteration 1000 / 5000: loss 1.547593
# iteration 1100 / 5000: loss 1.706309
# iteration 1200 / 5000: loss 1.591273
# iteration 1300 / 5000: loss 1.620835
# iteration 1400 / 5000: loss 1.448767
# iteration 1500 / 5000: loss 1.468726
# iteration 1600 / 5000: loss 1.469985
# iteration 1700 / 5000: loss 1.441074
# iteration 1800 / 5000: loss 1.482924
# iteration 1900 / 5000: loss 1.410030
# iteration 2000 / 5000: loss 1.510664
# iteration 2100 / 5000: loss 1.430454
# iteration 2200 / 5000: loss 1.440566
# iteration 2300 / 5000: loss 1.473327
# iteration 2400 / 5000: loss 1.435215
# iteration 2500 / 5000: loss 1.293328
# iteration 2600 / 5000: loss 1.499412
# iteration 2700 / 5000: loss 1.459031
# iteration 2800 / 5000: loss 1.451998
# iteration 2900 / 5000: loss 1.522772
# iteration 3000 / 5000: loss 1.424271
# iteration 3100 / 5000: loss 1.380502
# iteration 3200 / 5000: loss 1.437199
# iteration 3300 / 5000: loss 1.369896
# iteration 3400 / 5000: loss 1.317505
# iteration 3500 / 5000: loss 1.360970
# iteration 3600 / 5000: loss 1.334213
# iteration 3700 / 5000: loss 1.302265
# iteration 3800 / 5000: loss 1.265816
# iteration 3900 / 5000: loss 1.341991
# iteration 4000 / 5000: loss 1.298605
# iteration 4100 / 5000: loss 1.344569
# iteration 4200 / 5000: loss 1.392568
# iteration 4300 / 5000: loss 1.302304
# iteration 4400 / 5000: loss 1.392803
# iteration 4500 / 5000: loss 1.482206
# iteration 4600 / 5000: loss 1.301526
# iteration 4700 / 5000: loss 1.189450
# iteration 4800 / 5000: loss 1.294426
# iteration 4900 / 5000: loss 1.297333
# iteration 0 / 5000: loss 2.305547
# iteration 100 / 5000: loss 2.071252
# iteration 200 / 5000: loss 2.010365
# iteration 300 / 5000: loss 1.785001
# iteration 400 / 5000: loss 1.717897
# iteration 500 / 5000: loss 1.649370
# iteration 600 / 5000: loss 1.561218
# iteration 700 / 5000: loss 1.683759
# iteration 800 / 5000: loss 1.586059
# iteration 900 / 5000: loss 1.680340
# iteration 1000 / 5000: loss 1.525455
# iteration 1100 / 5000: loss 1.649779
# iteration 1200 / 5000: loss 1.421299
# iteration 1300 / 5000: loss 1.467910
# iteration 1400 / 5000: loss 1.399386
# iteration 1500 / 5000: loss 1.476850
# iteration 1600 / 5000: loss 1.439694
# iteration 1700 / 5000: loss 1.395675
# iteration 1800 / 5000: loss 1.559350
# iteration 1900 / 5000: loss 1.430718
# iteration 2000 / 5000: loss 1.422682
# iteration 2100 / 5000: loss 1.404077
# iteration 2200 / 5000: loss 1.333269
# iteration 2300 / 5000: loss 1.365452
# iteration 2400 / 5000: loss 1.404255
# iteration 2500 / 5000: loss 1.385816
# iteration 2600 / 5000: loss 1.371066
# iteration 2700 / 5000: loss 1.286529
# iteration 2800 / 5000: loss 1.332446
# iteration 2900 / 5000: loss 1.449124
# iteration 3000 / 5000: loss 1.549662
# iteration 3100 / 5000: loss 1.292405
# iteration 3200 / 5000: loss 1.243479
# iteration 3300 / 5000: loss 1.303253
# iteration 3400 / 5000: loss 1.296792
# iteration 3500 / 5000: loss 1.336275
# iteration 3600 / 5000: loss 1.418437
# iteration 3700 / 5000: loss 1.360890
# iteration 3800 / 5000: loss 1.336508
# iteration 3900 / 5000: loss 1.302776
# iteration 4000 / 5000: loss 1.444428
# iteration 4100 / 5000: loss 1.210100
# iteration 4200 / 5000: loss 1.434082
# iteration 4300 / 5000: loss 1.472269
# iteration 4400 / 5000: loss 1.340069
# iteration 4500 / 5000: loss 1.358285
# iteration 4600 / 5000: loss 1.269691
# iteration 4700 / 5000: loss 1.243954
# iteration 4800 / 5000: loss 1.258231
# iteration 4900 / 5000: loss 1.279202
# iteration 0 / 5000: loss 2.306428
# iteration 100 / 5000: loss 2.301863
# iteration 200 / 5000: loss 2.270604
# iteration 300 / 5000: loss 2.210476
# iteration 400 / 5000: loss 2.080261
# iteration 500 / 5000: loss 2.099819
# iteration 600 / 5000: loss 2.053174
# iteration 700 / 5000: loss 2.023848
# iteration 800 / 5000: loss 1.861038
# iteration 900 / 5000: loss 1.957105
# iteration 1000 / 5000: loss 1.933640
# iteration 1100 / 5000: loss 1.899259
# iteration 1200 / 5000: loss 1.839991
# iteration 1300 / 5000: loss 1.843822
# iteration 1400 / 5000: loss 1.791963
# iteration 1500 / 5000: loss 1.924066
# iteration 1600 / 5000: loss 1.905582
# iteration 1700 / 5000: loss 1.735618
# iteration 1800 / 5000: loss 1.793735
# iteration 1900 / 5000: loss 1.729563
# iteration 2000 / 5000: loss 1.765336
# iteration 2100 / 5000: loss 1.798943
# iteration 2200 / 5000: loss 1.805123
# iteration 2300 / 5000: loss 1.730283
# iteration 2400 / 5000: loss 1.708561
# iteration 2500 / 5000: loss 1.715302
# iteration 2600 / 5000: loss 1.680471
# iteration 2700 / 5000: loss 1.715109
# iteration 2800 / 5000: loss 1.544598
# iteration 2900 / 5000: loss 1.805081
# iteration 3000 / 5000: loss 1.701467
# iteration 3100 / 5000: loss 1.712274
# iteration 3200 / 5000: loss 1.657857
# iteration 3300 / 5000: loss 1.739532
# iteration 3400 / 5000: loss 1.612885
# iteration 3500 / 5000: loss 1.658729
# iteration 3600 / 5000: loss 1.579198
# iteration 3700 / 5000: loss 1.641939
# iteration 3800 / 5000: loss 1.644389
# iteration 3900 / 5000: loss 1.616710
# iteration 4000 / 5000: loss 1.705698
# iteration 4100 / 5000: loss 1.696666
# iteration 4200 / 5000: loss 1.620334
# iteration 4300 / 5000: loss 1.598932
# iteration 4400 / 5000: loss 1.755995
# iteration 4500 / 5000: loss 1.591333
# iteration 4600 / 5000: loss 1.643180
# iteration 4700 / 5000: loss 1.627072
# iteration 4800 / 5000: loss 1.585536
# iteration 4900 / 5000: loss 1.648033
# iteration 0 / 5000: loss 2.306423
# iteration 100 / 5000: loss 2.268199
# iteration 200 / 5000: loss 2.108708
# iteration 300 / 5000: loss 2.028181
# iteration 400 / 5000: loss 1.962831
# iteration 500 / 5000: loss 1.834356
# iteration 600 / 5000: loss 1.884167
# iteration 700 / 5000: loss 1.767331
# iteration 800 / 5000: loss 1.804231
# iteration 900 / 5000: loss 1.734288
# iteration 1000 / 5000: loss 1.749395
# iteration 1100 / 5000: loss 1.746646
# iteration 1200 / 5000: loss 1.682524
# iteration 1300 / 5000: loss 1.580628
# iteration 1400 / 5000: loss 1.736377
# iteration 1500 / 5000: loss 1.667214
# iteration 1600 / 5000: loss 1.614140
# iteration 1700 / 5000: loss 1.680155
# iteration 1800 / 5000: loss 1.671994
# iteration 1900 / 5000: loss 1.657890
# iteration 2000 / 5000: loss 1.662714
# iteration 2100 / 5000: loss 1.616278
# iteration 2200 / 5000: loss 1.604125
# iteration 2300 / 5000: loss 1.648101
# iteration 2400 / 5000: loss 1.480256
# iteration 2500 / 5000: loss 1.511264
# iteration 2600 / 5000: loss 1.476623
# iteration 2700 / 5000: loss 1.541057
# iteration 2800 / 5000: loss 1.486208
# iteration 2900 / 5000: loss 1.404402
# iteration 3000 / 5000: loss 1.452134
# iteration 3100 / 5000: loss 1.562015
# iteration 3200 / 5000: loss 1.434938
# iteration 3300 / 5000: loss 1.419637
# iteration 3400 / 5000: loss 1.487820
# iteration 3500 / 5000: loss 1.668176
# iteration 3600 / 5000: loss 1.555783
# iteration 3700 / 5000: loss 1.512345
# iteration 3800 / 5000: loss 1.540069
# iteration 3900 / 5000: loss 1.453511
# iteration 4000 / 5000: loss 1.552218
# iteration 4100 / 5000: loss 1.495893
# iteration 4200 / 5000: loss 1.607685
# iteration 4300 / 5000: loss 1.465740
# iteration 4400 / 5000: loss 1.457889
# iteration 4500 / 5000: loss 1.462189
# iteration 4600 / 5000: loss 1.587524
# iteration 4700 / 5000: loss 1.430434
# iteration 4800 / 5000: loss 1.427528
# iteration 4900 / 5000: loss 1.438076
# iteration 0 / 5000: loss 2.306438
# iteration 100 / 5000: loss 2.164161
# iteration 200 / 5000: loss 1.978490
# iteration 300 / 5000: loss 1.888802
# iteration 400 / 5000: loss 1.958117
# iteration 500 / 5000: loss 1.743223
# iteration 600 / 5000: loss 1.738165
# iteration 700 / 5000: loss 1.714813
# iteration 800 / 5000: loss 1.706226
# iteration 900 / 5000: loss 1.680006
# iteration 1000 / 5000: loss 1.792499
# iteration 1100 / 5000: loss 1.616451
# iteration 1200 / 5000: loss 1.587870
# iteration 1300 / 5000: loss 1.605705
# iteration 1400 / 5000: loss 1.660961
# iteration 1500 / 5000: loss 1.553066
# iteration 1600 / 5000: loss 1.517260
# iteration 1700 / 5000: loss 1.567261
# iteration 1800 / 5000: loss 1.490988
# iteration 1900 / 5000: loss 1.617806
# iteration 2000 / 5000: loss 1.490060
# iteration 2100 / 5000: loss 1.493688
# iteration 2200 / 5000: loss 1.534330
# iteration 2300 / 5000: loss 1.542297
# iteration 2400 / 5000: loss 1.451679
# iteration 2500 / 5000: loss 1.411386
# iteration 2600 / 5000: loss 1.442256
# iteration 2700 / 5000: loss 1.519022
# iteration 2800 / 5000: loss 1.450871
# iteration 2900 / 5000: loss 1.532173
# iteration 3000 / 5000: loss 1.452326
# iteration 3100 / 5000: loss 1.513268
# iteration 3200 / 5000: loss 1.416962
# iteration 3300 / 5000: loss 1.330997
# iteration 3400 / 5000: loss 1.417376
# iteration 3500 / 5000: loss 1.428060
# iteration 3600 / 5000: loss 1.525181
# iteration 3700 / 5000: loss 1.480949
# iteration 3800 / 5000: loss 1.489280
# iteration 3900 / 5000: loss 1.432296
# iteration 4000 / 5000: loss 1.337824
# iteration 4100 / 5000: loss 1.549587
# iteration 4200 / 5000: loss 1.393326
# iteration 4300 / 5000: loss 1.321105
# iteration 4400 / 5000: loss 1.446484
# iteration 4500 / 5000: loss 1.461274
# iteration 4600 / 5000: loss 1.420156
# iteration 4700 / 5000: loss 1.453700
# iteration 4800 / 5000: loss 1.316896
# iteration 4900 / 5000: loss 1.500728
# iteration 0 / 5000: loss 2.306387
# iteration 100 / 5000: loss 2.058142
# iteration 200 / 5000: loss 1.935565
# iteration 300 / 5000: loss 1.818130
# iteration 400 / 5000: loss 1.835809
# iteration 500 / 5000: loss 1.824569
# iteration 600 / 5000: loss 1.747755
# iteration 700 / 5000: loss 1.635211
# iteration 800 / 5000: loss 1.701822
# iteration 900 / 5000: loss 1.683528
# iteration 1000 / 5000: loss 1.519830
# iteration 1100 / 5000: loss 1.617944
# iteration 1200 / 5000: loss 1.506206
# iteration 1300 / 5000: loss 1.487013
# iteration 1400 / 5000: loss 1.536840
# iteration 1500 / 5000: loss 1.420536
# iteration 1600 / 5000: loss 1.554112
# iteration 1700 / 5000: loss 1.619470
# iteration 1800 / 5000: loss 1.488869
# iteration 1900 / 5000: loss 1.532435
# iteration 2000 / 5000: loss 1.635358
# iteration 2100 / 5000: loss 1.459954
# iteration 2200 / 5000: loss 1.473862
# iteration 2300 / 5000: loss 1.360301
# iteration 2400 / 5000: loss 1.518149
# iteration 2500 / 5000: loss 1.334418
# iteration 2600 / 5000: loss 1.442503
# iteration 2700 / 5000: loss 1.482509
# iteration 2800 / 5000: loss 1.376791
# iteration 2900 / 5000: loss 1.440170
# iteration 3000 / 5000: loss 1.394381
# iteration 3100 / 5000: loss 1.365111
# iteration 3200 / 5000: loss 1.382406
# iteration 3300 / 5000: loss 1.390180
# iteration 3400 / 5000: loss 1.353184
# iteration 3500 / 5000: loss 1.385440
# iteration 3600 / 5000: loss 1.348595
# iteration 3700 / 5000: loss 1.363417
# iteration 3800 / 5000: loss 1.310966
# iteration 3900 / 5000: loss 1.379737
# iteration 4000 / 5000: loss 1.448253
# iteration 4100 / 5000: loss 1.379863
# iteration 4200 / 5000: loss 1.382100
# iteration 4300 / 5000: loss 1.317311
# iteration 4400 / 5000: loss 1.414294
# iteration 4500 / 5000: loss 1.295211
# iteration 4600 / 5000: loss 1.454243
# iteration 4700 / 5000: loss 1.349860
# iteration 4800 / 5000: loss 1.355064
# iteration 4900 / 5000: loss 1.296285
# iteration 0 / 5000: loss 2.306477
# iteration 100 / 5000: loss 2.104579
# iteration 200 / 5000: loss 1.903302
# iteration 300 / 5000: loss 1.817860
# iteration 400 / 5000: loss 1.699623
# iteration 500 / 5000: loss 1.632691
# iteration 600 / 5000: loss 1.665556
# iteration 700 / 5000: loss 1.636699
# iteration 800 / 5000: loss 1.637632
# iteration 900 / 5000: loss 1.458354
# iteration 1000 / 5000: loss 1.648063
# iteration 1100 / 5000: loss 1.464310
# iteration 1200 / 5000: loss 1.475255
# iteration 1300 / 5000: loss 1.377808
# iteration 1400 / 5000: loss 1.479446
# iteration 1500 / 5000: loss 1.585847
# iteration 1600 / 5000: loss 1.534378
# iteration 1700 / 5000: loss 1.429109
# iteration 1800 / 5000: loss 1.472659
# iteration 1900 / 5000: loss 1.388582
# iteration 2000 / 5000: loss 1.483352
# iteration 2100 / 5000: loss 1.455910
# iteration 2200 / 5000: loss 1.379564
# iteration 2300 / 5000: loss 1.485499
# iteration 2400 / 5000: loss 1.469159
# iteration 2500 / 5000: loss 1.407716
# iteration 2600 / 5000: loss 1.215765
# iteration 2700 / 5000: loss 1.438191
# iteration 2800 / 5000: loss 1.439337
# iteration 2900 / 5000: loss 1.507417
# iteration 3000 / 5000: loss 1.513415
# iteration 3100 / 5000: loss 1.478393
# iteration 3200 / 5000: loss 1.380612
# iteration 3300 / 5000: loss 1.419476
# iteration 3400 / 5000: loss 1.175140
# iteration 3500 / 5000: loss 1.310556
# iteration 3600 / 5000: loss 1.410732
# iteration 3700 / 5000: loss 1.369631
# iteration 3800 / 5000: loss 1.447289
# iteration 3900 / 5000: loss 1.304290
# iteration 4000 / 5000: loss 1.443177
# iteration 4100 / 5000: loss 1.413698
# iteration 4200 / 5000: loss 1.331706
# iteration 4300 / 5000: loss 1.350529
# iteration 4400 / 5000: loss 1.317216
# iteration 4500 / 5000: loss 1.200336
# iteration 4600 / 5000: loss 1.252509
# iteration 4700 / 5000: loss 1.227405
# iteration 4800 / 5000: loss 1.374169
# iteration 4900 / 5000: loss 1.389275
# hs 1.000000e+02 lr 1.000000e-04 val accuracy: 0.429000
# hs 1.000000e+02 lr 2.000000e-04 val accuracy: 0.476000
# hs 1.000000e+02 lr 3.000000e-04 val accuracy: 0.495000
# hs 1.000000e+02 lr 4.000000e-04 val accuracy: 0.525000
# hs 1.000000e+02 lr 5.000000e-04 val accuracy: 0.531000
# hs 2.000000e+02 lr 1.000000e-04 val accuracy: 0.442000
# hs 2.000000e+02 lr 2.000000e-04 val accuracy: 0.477000
# hs 2.000000e+02 lr 3.000000e-04 val accuracy: 0.492000
# hs 2.000000e+02 lr 4.000000e-04 val accuracy: 0.514000
# hs 2.000000e+02 lr 5.000000e-04 val accuracy: 0.525000
# hs 3.000000e+02 lr 1.000000e-04 val accuracy: 0.446000
# hs 3.000000e+02 lr 2.000000e-04 val accuracy: 0.481000
# hs 3.000000e+02 lr 3.000000e-04 val accuracy: 0.502000
# hs 3.000000e+02 lr 4.000000e-04 val accuracy: 0.526000
# hs 3.000000e+02 lr 5.000000e-04 val accuracy: 0.521000
# hs 4.000000e+02 lr 1.000000e-04 val accuracy: 0.445000
# hs 4.000000e+02 lr 2.000000e-04 val accuracy: 0.485000
# hs 4.000000e+02 lr 3.000000e-04 val accuracy: 0.514000
# hs 4.000000e+02 lr 4.000000e-04 val accuracy: 0.528000
# hs 4.000000e+02 lr 5.000000e-04 val accuracy: 0.521000
# hs 5.000000e+02 lr 1.000000e-04 val accuracy: 0.443000
# hs 5.000000e+02 lr 2.000000e-04 val accuracy: 0.483000
# hs 5.000000e+02 lr 3.000000e-04 val accuracy: 0.507000
# hs 5.000000e+02 lr 4.000000e-04 val accuracy: 0.525000
# hs 5.000000e+02 lr 5.000000e-04 val accuracy: 0.541000

# %%
# Print your validation accuracy: this should be above 48%
val_acc = (best_net.predict(X_val) == y_val).mean()
print('Validation accuracy: ', val_acc)
# Out:
# Validation accuracy:  0.541

# %%
# Visualize the weights of the best network
show_net_weights(best_net)

# %% [markdown]
# # Run on the test set
# When you are done experimenting, you should evaluate your final trained network on the test set; you should get above 48%.

# %%
# Print your test accuracy: this should be above 48%
test_acc = (best_net.predict(X_test) == y_test).mean()
print('Test accuracy: ', test_acc)
# Out:
# Test accuracy:  0.55

# %% [markdown]
# **Inline Question**
#
# Now that you have trained a Neural Network classifier, you may find that your testing accuracy is much lower than the training accuracy. In what ways can we decrease this gap? Select all that apply.
#
# 1. Train on a larger dataset.
# 2. Add more hidden units.
# 3. Increase the regularization strength.
# 4. None of the above.
#
# $\color{blue}{\textit Your Answer:}$
#
# $\color{blue}{\textit Your Explanation:}$

# %% [markdown]
# ---
# # IMPORTANT
#
# This is the end of this question. Please do the following:
#
# 1. Click `File -> Save` to make sure the latest checkpoint of this notebook is saved to your Drive.
# 2. Execute the cell below to download the modified `.py` files back to your drive.

# %%
import os

FOLDER_TO_SAVE = os.path.join('drive/My Drive/', FOLDERNAME)
FILES_TO_SAVE = ['cs231n/classifiers/neural_net.py']

for files in FILES_TO_SAVE:
  with open(os.path.join(FOLDER_TO_SAVE, '/'.join(files.split('/')[1:])), 'w') as f:
    f.write(''.join(open(files).readlines()))
